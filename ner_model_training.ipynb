# %%
import pandas as pd

# %%
df = pd.read_csv('manualy_annotated_dataset2.csv')
df
# Out:
#                                                    req  \
# 0    Each college has a website\nEach college is st...
# 1    Among these teachers, one of them is responsib...
# 2    A teacher is defined by his surname, first nam...
# 3             Each teacher teaches only one subject.\n
# 4    Students take several subjects and receive a m...
# ..                                                 ...
# 299  Packets contain an originator, a destination a...
# 300        A LAN is a circular configuration of nodes.
# 301   Each document is composed of one or more sheets.
# 302  A sheet contains text and geometrical objects ...
# 303  We consider the following four geometric objec...
#
#                                                    pos  \
# 0    DET NOUN VERB DET NOUN SPACE DET NOUN AUX VERB...
# 1    ADP DET NOUN PUNCT NUM ADP PRON AUX ADJ ADP DE...
# 2    DET NOUN AUX VERB ADP PRON NOUN PUNCT ADJ NOUN...
# 3               DET NOUN VERB ADV NUM NOUN PUNCT SPACE
# 4    NOUN VERB ADJ NOUN CCONJ VERB DET NOUN ADP PRO...
# ..                                                 ...
# 299  NOUN VERB DET NOUN PUNCT DET NOUN CCONJ NOUN P...
# 300          DET PROPN AUX DET ADJ NOUN ADP NOUN PUNCT
# 301     DET NOUN AUX VERB ADP NUM CCONJ ADJ NOUN PUNCT
# 302  DET NOUN VERB NOUN CCONJ ADJ NOUN PRON VERB NU...
# 303  PRON VERB DET VERB NUM ADJ NOUN PUNCT NOUN PUN...
#
#                                                 labels
# 0    O entity relationship O attr O O entity O rela...
# 1     O O entity O O O O O relationship O O entity O O
# 2    O entity O relationship O O attr O O attr O at...
# 3                 O entity relationship O O entity O O
# 4     entity relationship O entity O O O O O O O O O O
# ..                                                 ...
# 299  entity O O attr O O attr O attr O O O O O O O ...
# 300                        O entity O O O O O entity O
# 301           O entity O relationship O O O O entity O
# 302  O entity relationship entity O O O O O O O O O...
# 303  O O O O O O O O entity O entity O entity O ent...
#
# [304 rows x 3 columns]

# %%
import spacy

nlp = spacy.blank("en")

TRAIN_DATA = []
for sentence, labels in zip(df.req, df.labels):
    doc = nlp(sentence)
    entities = []
    for token, label in zip(doc, labels.split()):
        if label == "entity":
            entities.append([token.idx, token.idx + len(token.text), "CLASS"])
        elif label == "attr":
            entities.append([token.idx, token.idx + len(token.text), "ATTRIBUTE"])
        elif label == "relationship":
            entities.append([token.idx, token.idx + len(token.text), "RELATIONSHIP"])

    TRAIN_DATA.append([sentence, {"entities": entities}])

TRAIN_DATA
# Out:
# [['Each college has a website\nEach college is structured into departments, each of which brings together specific teachers.',
#   {'entities': [[5, 12, 'CLASS'],
#     [13, 16, 'RELATIONSHIP'],
#     [19, 26, 'ATTRIBUTE'],
#     [32, 39, 'CLASS'],
#     [43, 53, 'RELATIONSHIP'],
#     [59, 70, 'CLASS'],
#     [86, 92, 'RELATIONSHIP'],
#     [111, 119, 'CLASS']]}],
#  ['Among these teachers, one of them is responsible for the department.\n',
#   {'entities': [[12, 20, 'CLASS'],
#     [37, 48, 'RELATIONSHIP'],
#     [57, 67, 'CLASS']]}],
#  ['A teacher is defined by his surname, first name, phone, email, date of taking office and his index.\n',
#   {'entities': [[2, 9, 'CLASS'],
#     [13, 20, 'RELATIONSHIP'],
#     [28, 35, 'ATTRIBUTE'],
#     [43, 47, 'ATTRIBUTE'],
#     [49, 54, 'ATTRIBUTE'],
#     [56, 61, 'ATTRIBUTE'],
#     [63, 67, 'ATTRIBUTE'],
#     [93, 98, 'ATTRIBUTE']]}],
#  ['Each teacher teaches only one subject.\n',
#   {'entities': [[5, 12, 'CLASS'],
#     [13, 20, 'RELATIONSHIP'],
#     [30, 37, 'CLASS']]}],
#  ['Students take several subjects and receive a mark for each of them.\n',
#   {'entities': [[0, 8, 'CLASS'], [9, 13, 'RELATIONSHIP'], [22, 30, 'CLASS']]}],
#  ['For each student, we want to manage his name, first name, phone, email, as well as his year of entry to college.\n',
#   {'entities': [[9, 16, 'CLASS'],
#     [40, 44, 'ATTRIBUTE'],
#     [52, 56, 'ATTRIBUTE'],
#     [58, 63, 'ATTRIBUTE'],
#     [65, 70, 'ATTRIBUTE'],
#     [87, 91, 'ATTRIBUTE'],
#     [104, 111, 'CLASS']]}],
#  ['A subject can be taught by several teachers but always takes place in the same classroom (each having a specific number of places).\n',
#   {'entities': [[2, 9, 'CLASS'],
#     [17, 23, 'RELATIONSHIP'],
#     [35, 43, 'CLASS'],
#     [79, 88, 'CLASS'],
#     [113, 119, 'ATTRIBUTE']]}],
#  ['We want to be able to calculate the average by subject as well as by department\nWe also want to calculate the general average of a student and be able to display the subjects in which he has not been noted\nFinally, we must be able to print the data sheet (, first name, phone, email) of a teacher or a student.',
#   {'entities': [[47, 54, 'CLASS'],
#     [69, 79, 'CLASS'],
#     [131, 138, 'CLASS'],
#     [166, 174, 'CLASS'],
#     [187, 190, 'RELATIONSHIP'],
#     [264, 268, 'ATTRIBUTE'],
#     [270, 275, 'ATTRIBUTE'],
#     [277, 282, 'ATTRIBUTE'],
#     [289, 296, 'CLASS'],
#     [302, 309, 'CLASS']]}],
#  ['Consider the following sentences:\n\nA directory contains files\nA room contains walls\nModems and keyboards are input/output devices\nA stock transaction is a purchase or a sale\nA bank account can belong to a natural or legal person',
#   {'entities': [[37, 46, 'CLASS'],
#     [47, 55, 'RELATIONSHIP'],
#     [56, 61, 'CLASS'],
#     [64, 68, 'CLASS'],
#     [69, 77, 'RELATIONSHIP'],
#     [78, 83, 'CLASS'],
#     [84, 90, 'CLASS'],
#     [95, 104, 'CLASS'],
#     [105, 108, 'RELATIONSHIP'],
#     [122, 129, 'CLASS'],
#     [138, 149, 'CLASS'],
#     [150, 152, 'RELATIONSHIP'],
#     [155, 163, 'CLASS'],
#     [169, 173, 'CLASS'],
#     [181, 188, 'CLASS'],
#     [193, 199, 'RELATIONSHIP'],
#     [205, 212, 'CLASS'],
#     [216, 221, 'CLASS']]}],
#  ['Either in a school that performs the following functions:\nDevelop catalogs that describe the courses and give the estimated dates of the sessions.\n',
#   {'entities': [[93, 100, 'CLASS'], [137, 145, 'CLASS']]}],
#  ['Register people who wish to participate in the sessions and send them their invitation.\n',
#   {'entities': [[9, 15, 'CLASS'],
#     [28, 39, 'RELATIONSHIP'],
#     [47, 55, 'CLASS']]}],
#  ['Determine the trainers who will lead the sessions.',
#   {'entities': [[14, 22, 'CLASS'],
#     [32, 36, 'RELATIONSHIP'],
#     [41, 49, 'CLASS']]}],
#  ['Some sessions may be led by individual contractors.\n',
#   {'entities': [[5, 13, 'CLASS'],
#     [21, 24, 'RELATIONSHIP'],
#     [39, 50, 'CLASS']]}],
#  ['Some courses are organized into sectors.',
#   {'entities': [[5, 12, 'CLASS'],
#     [17, 26, 'RELATIONSHIP'],
#     [32, 39, 'CLASS']]}],
#  ['The courses use referenced documents.',
#   {'entities': [[4, 11, 'CLASS'],
#     [12, 15, 'RELATIONSHIP'],
#     [27, 36, 'CLASS']]}],
#  ['A person is characterized by his name, his first name, his sex and his age.',
#   {'entities': [[2, 8, 'CLASS'],
#     [33, 37, 'ATTRIBUTE'],
#     [49, 53, 'ATTRIBUTE'],
#     [59, 62, 'ATTRIBUTE'],
#     [71, 74, 'ATTRIBUTE']]}],
#  ['The attributes of the class are private; the name, the first name and the age of the person must be accessible by public operations.',
#   {'entities': [[45, 49, 'ATTRIBUTE'],
#     [61, 65, 'ATTRIBUTE'],
#     [74, 77, 'ATTRIBUTE'],
#     [85, 91, 'CLASS']]}],
#  ['In a university there are different classrooms, offices \nand departments.',
#   {'entities': [[5, 15, 'CLASS'],
#     [36, 46, 'CLASS'],
#     [48, 55, 'CLASS'],
#     [61, 72, 'CLASS']]}],
#  ['A department has a name and it \ncontains many offices.',
#   {'entities': [[2, 12, 'CLASS'],
#     [19, 23, 'ATTRIBUTE'],
#     [32, 40, 'RELATIONSHIP'],
#     [46, 53, 'CLASS']]}],
#  ['A person working at the \nuniversity has a unique ID and can be a professor or \nan employee.\n',
#   {'entities': [[2, 8, 'CLASS'],
#     [9, 16, 'RELATIONSHIP'],
#     [25, 35, 'CLASS'],
#     [49, 51, 'ATTRIBUTE'],
#     [60, 62, 'RELATIONSHIP'],
#     [65, 74, 'CLASS'],
#     [82, 90, 'CLASS']]}],
#  ['A professor can be a full, associate or assistant \nprofessor and he/she is enrolled in one department.\n',
#   {'entities': [[2, 11, 'CLASS'],
#     [16, 18, 'RELATIONSHIP'],
#     [21, 25, 'CLASS'],
#     [27, 36, 'CLASS'],
#     [40, 49, 'CLASS'],
#     [51, 60, 'CLASS'],
#     [75, 83, 'RELATIONSHIP'],
#     [91, 101, 'CLASS']]}],
#  ['Offices and classrooms have a number ID, and a \nclassroom has a number of seats.\n',
#   {'entities': [[0, 7, 'CLASS'],
#     [12, 22, 'CLASS'],
#     [37, 39, 'ATTRIBUTE'],
#     [48, 57, 'CLASS'],
#     [74, 79, 'ATTRIBUTE']]}],
#  ['Every employee works in an office.\n',
#   {'entities': [[6, 14, 'CLASS'],
#     [15, 20, 'RELATIONSHIP'],
#     [27, 33, 'CLASS']]}],
#  ['The factory produces several lines of furniture, each with a different name and consisting of several pieces of furniture of different types (beds, tables, chairs, …).',
#   {'entities': [[29, 34, 'CLASS'],
#     [71, 75, 'ATTRIBUTE'],
#     [80, 90, 'RELATIONSHIP'],
#     [102, 108, 'CLASS'],
#     [135, 140, 'ATTRIBUTE']]}],
#  ['All furniture pieces have a type, a single reference (eg CC6578) and a selling price.',
#   {'entities': [[14, 20, 'CLASS'],
#     [28, 32, 'ATTRIBUTE'],
#     [43, 52, 'ATTRIBUTE'],
#     [79, 84, 'ATTRIBUTE']]}],
#  ['The major competitive advantage of this innovative plant is the fact that each component produced can be used in more than one piece of furniture.',
#   {'entities': [[79, 88, 'CLASS'], [127, 132, 'CLASS']]}],
#  ['Each piece of furniture is thus composed of several components.',
#   {'entities': [[5, 10, 'CLASS'],
#     [32, 40, 'RELATIONSHIP'],
#     [52, 62, 'CLASS']]}],
#  ['The same component can be used more than once in the same piece.',
#   {'entities': [[9, 18, 'CLASS'], [58, 63, 'CLASS']]}],
#  ['Every type of component produced is assigned a unique numerical code, a manufacturing price and a type (screw, hinge, shelf …).',
#   {'entities': [[6, 10, 'ATTRIBUTE'],
#     [14, 23, 'CLASS'],
#     [64, 68, 'ATTRIBUTE'],
#     [86, 91, 'ATTRIBUTE'],
#     [98, 102, 'ATTRIBUTE']]}],
#  ['The furniture is then sold in various stores throughout the world.',
#   {'entities': [[38, 44, 'CLASS']]}],
#  ['Each store has a different address and a fax number.',
#   {'entities': [[5, 10, 'CLASS'],
#     [27, 34, 'ATTRIBUTE'],
#     [41, 44, 'ATTRIBUTE'],
#     [45, 51, 'ATTRIBUTE']]}],
#  ['To make the manufacturing process more efficient, stores have to place orders everytime they need to replenish their stock.',
#   {'entities': [[50, 56, 'CLASS'],
#     [65, 70, 'RELATIONSHIP'],
#     [71, 77, 'CLASS']]}],
#  ['These orders must also be stored in the database.',
#   {'entities': [[6, 12, 'CLASS'],
#     [26, 32, 'RELATIONSHIP'],
#     [40, 48, 'CLASS']]}],
#  ['Each order has a order number, a date, the store that placed the order as well as a list of all the ordered furniture and their quantities.',
#   {'entities': [[5, 10, 'CLASS'],
#     [17, 22, 'CLASS'],
#     [23, 29, 'ATTRIBUTE'],
#     [33, 37, 'ATTRIBUTE'],
#     [43, 48, 'CLASS'],
#     [65, 70, 'CLASS']]}],
#  ['It should be possible to store the national id number (NIN), tax identification number (TIN), name and address for every client.',
#   {'entities': [[61, 64, 'ATTRIBUTE'],
#     [94, 98, 'ATTRIBUTE'],
#     [103, 110, 'ATTRIBUTE'],
#     [121, 127, 'CLASS']]}],
#  ['The NIN and TIN must be different for every client and all clients should have at least a TIN and a name.',
#   {'entities': [[44, 50, 'CLASS'], [100, 104, 'ATTRIBUTE']]}],
#  ['The database should also contain information about the bicycle models that can be rented-',
#   {'entities': [[55, 62, 'CLASS']]}],
#  ['Each model has an unique name, a type (that can only be road, mountain, bmx or hybrid) and the number of gears.',
#   {'entities': [[25, 29, 'ATTRIBUTE'],
#     [33, 37, 'ATTRIBUTE'],
#     [105, 110, 'ATTRIBUTE']]}],
#  ['Each bicycle has a unique identifying number and a model.',
#   {'entities': [[5, 12, 'CLASS']]}],
#  ['The company has several different stores where bicycles can be picked up and returned.',
#   {'entities': [[34, 40, 'CLASS']]}],
#  ['Each one of these stores is identified by an unique name and has an address (both mandatory).',
#   {'entities': [[18, 24, 'CLASS'],
#     [52, 56, 'ATTRIBUTE'],
#     [68, 75, 'ATTRIBUTE']]}],
#  ['When a reservation is made, the following data must be known: which client did the reservation, when will he pick up the bike (day), which bike model he wants and where will he pick up the bike (store).',
#   {'entities': [[7, 18, 'CLASS'],
#     [68, 74, 'CLASS'],
#     [75, 78, 'RELATIONSHIP'],
#     [83, 94, 'CLASS']]}],
#  ['Consider a company with six factories that builds engine components.',
#   {'entities': [[28, 37, 'CLASS']]}],
#  ['A single factory takes care of the assembly,\nCustomers place orders, priority customer places orders first with 20% more of the order.',
#   {'entities': [[9, 16, 'CLASS'],
#     [45, 54, 'CLASS'],
#     [55, 60, 'RELATIONSHIP'],
#     [61, 67, 'CLASS'],
#     [94, 100, 'CLASS']]}],
#  ['Orders are received by the sales department.',
#   {'entities': [[0, 6, 'CLASS'], [27, 32, 'CLASS']]}],
#  ['If the customer places more than ten orders then he has priority.',
#   {'entities': [[37, 43, 'CLASS']]}],
#  ['After processing the orders received, the sales department obtains a breakdown of the parts: manufactured parts and subcontracted parts.\n',
#   {'entities': [[21, 27, 'CLASS'], [42, 47, 'CLASS']]}],
#  ['The sales department can print two types of listings: home listing sent to the factory, and a listing of the subtracted components sent to the stock management department which takes care of the supply of raw materials.',
#   {'entities': [[4, 9, 'CLASS'],
#     [25, 30, 'RELATIONSHIP'],
#     [67, 71, 'RELATIONSHIP'],
#     [79, 86, 'CLASS'],
#     [109, 119, 'CLASS'],
#     [131, 135, 'RELATIONSHIP'],
#     [149, 159, 'CLASS']]}],
#  ['Among the tasks also of the sales department is the follow-up of invoicing.',
#   {'entities': [[28, 33, 'CLASS']]}],
#  ['Or a media library for the borrowing of works by registered customers using a registration form containing their information (name, address, etc.).',
#   {'entities': [[11, 18, 'CLASS'],
#     [27, 36, 'RELATIONSHIP'],
#     [40, 45, 'CLASS'],
#     [60, 69, 'CLASS']]}],
#  ['We have three types of customers, a customer at reduced rates, a customer who subscribes for a year or a customer at a normal rate.',
#   {'entities': [[23, 32, 'CLASS'],
#     [36, 44, 'CLASS'],
#     [65, 73, 'CLASS'],
#     [105, 113, 'CLASS']]}],
#  ['A customer can borrow different types of work: audio, video or books.',
#   {'entities': [[2, 10, 'CLASS'],
#     [15, 21, 'RELATIONSHIP'],
#     [41, 45, 'CLASS'],
#     [47, 52, 'CLASS'],
#     [54, 59, 'CLASS'],
#     [63, 68, 'CLASS']]}],
#  ['These works are recorded in the media library by a unique code.',
#   {'entities': [[6, 11, 'CLASS'],
#     [16, 24, 'RELATIONSHIP'],
#     [38, 45, 'CLASS']]}],
#  ['On the other hand, there are documents that the customer cannot borrow, but can only be consulted on site.\n',
#   {'entities': [[48, 56, 'CLASS'], [64, 70, 'RELATIONSHIP']]}],
#  ['Each book has a particular type, for example the books have a "novel" type, or are of the "detective" type, etc.\n',
#   {'entities': [[5, 9, 'CLASS'],
#     [27, 31, 'ATTRIBUTE'],
#     [49, 54, 'CLASS'],
#     [70, 74, 'ATTRIBUTE'],
#     [102, 106, 'ATTRIBUTE']]}],
#  ['After borrowing a book, the librarian creates a borrowing sheet.',
#   {'entities': [[6, 15, 'RELATIONSHIP'],
#     [18, 22, 'CLASS'],
#     [48, 57, 'RELATIONSHIP']]}],
#  ['This sheet must contain the name of the customer, the date of loan and the date of return.',
#   {'entities': [[40, 48, 'CLASS']]}],
#  ['The librarian can add or delete a client or a work.\n',
#   {'entities': [[46, 50, 'CLASS']]}],
#  ['The borrowing of a document by a client follows certain rules:\nThe maximum number of documents to borrow is 5, if it exceeds this number then any new borrowing will be impossible.\n',
#   {'entities': [[4, 13, 'RELATIONSHIP'],
#     [98, 104, 'RELATIONSHIP'],
#     [150, 159, 'RELATIONSHIP']]}],
#  ['If the customer who has borrowed a document and who has not returned it, his return deadline will be blocked from making any new loan until he has returned the work, even if the maximum number of borrowing is not reached.',
#   {'entities': [[7, 15, 'CLASS'],
#     [160, 164, 'CLASS'],
#     [196, 205, 'RELATIONSHIP']]}],
#  ['A company consists of departments.',
#   {'entities': [[2, 9, 'CLASS'], [22, 33, 'CLASS']]}],
#  ['Departments are located in one or more offices.',
#   {'entities': [[0, 11, 'CLASS'], [39, 46, 'CLASS']]}],
#  ['One office acts as a headquarter.',
#   {'entities': [[4, 10, 'CLASS'], [21, 32, 'CLASS']]}],
#  ['Eachdepartment has a manager who is recruited from the set of employees.',
#   {'entities': [[21, 28, 'CLASS'],
#     [36, 45, 'RELATIONSHIP'],
#     [62, 71, 'CLASS']]}],
#  ['Each college has its own website.',
#   {'entities': [[5, 12, 'CLASS'],
#     [13, 16, 'RELATIONSHIP'],
#     [25, 32, 'CLASS']]}],
#  ['Each college is structured into departments, each of which has specific teachers.',
#   {'entities': [[5, 12, 'CLASS'],
#     [16, 26, 'RELATIONSHIP'],
#     [32, 43, 'CLASS'],
#     [59, 62, 'RELATIONSHIP'],
#     [72, 80, 'CLASS']]}],
#  ['Among these teachers, one of them is responsible for the department.',
#   {'entities': [[12, 20, 'CLASS'],
#     [37, 48, 'RELATIONSHIP'],
#     [57, 67, 'CLASS']]}],
#  ['A teacher is defined by his name, first name, phone number, e-mail, date of employment and his index.',
#   {'entities': [[2, 9, 'CLASS'],
#     [28, 32, 'ATTRIBUTE'],
#     [40, 44, 'ATTRIBUTE'],
#     [46, 51, 'ATTRIBUTE'],
#     [68, 72, 'ATTRIBUTE'],
#     [95, 100, 'ATTRIBUTE']]}],
#  ['Each teacher teaches only one subject.',
#   {'entities': [[5, 12, 'CLASS'],
#     [13, 20, 'RELATIONSHIP'],
#     [30, 37, 'CLASS']]}],
#  ['The students take several subjects and receive a grade for each of them.',
#   {'entities': [[4, 12, 'CLASS'],
#     [13, 17, 'RELATIONSHIP'],
#     [26, 34, 'CLASS']]}],
#  ['For each student, we want to manage his name, first name, phone number, e-mail, as well as his year of entry to the college.',
#   {'entities': [[9, 16, 'CLASS'],
#     [40, 44, 'ATTRIBUTE'],
#     [52, 56, 'ATTRIBUTE'],
#     [58, 63, 'ATTRIBUTE'],
#     [95, 99, 'ATTRIBUTE'],
#     [116, 123, 'CLASS']]}],
#  ['A subject can be taught by several teachers but always in the same classroom (each one having a certain number of seats).',
#   {'entities': [[2, 9, 'CLASS'], [35, 43, 'CLASS']]}],
#  ['We want to be able to calculate the average per subject and per department.',
#   {'entities': [[48, 55, 'CLASS'], [64, 74, 'CLASS']]}],
#  ["We also want to calculate a student's overall average and display the subjects in which he or she was not graded.",
#   {'entities': [[28, 35, 'CLASS'], [70, 78, 'CLASS']]}],
#  ['Finally, we want to be able to print the data sheet (, first name, phone, e-mail) of a teacher or a student.',
#   {'entities': [[61, 65, 'ATTRIBUTE'],
#     [67, 72, 'ATTRIBUTE'],
#     [87, 94, 'CLASS'],
#     [100, 107, 'CLASS']]}],
#  ['Design a system for a movie-shop, in order to\nhandle ordering of movies and browsing of the\ncatalogue of the store, and user subscriptions with\nrechargeable cards.\n',
#   {'entities': [[22, 27, 'CLASS'], [65, 71, 'CLASS']]}],
#  ['Only subscribers are allowed hiring movies with\ntheir own card.\n',
#   {'entities': [[5, 16, 'CLASS'],
#     [29, 35, 'RELATIONSHIP'],
#     [36, 42, 'CLASS']]}],
#  ['Both users and subscribers can buy a movie and\ntheir data are saved in the related order.\n',
#   {'entities': [[5, 10, 'CLASS'],
#     [15, 26, 'CLASS'],
#     [31, 34, 'RELATIONSHIP'],
#     [37, 42, 'CLASS']]}],
#  ['When a movie is not available it is ordered',
#   {'entities': [[7, 12, 'CLASS']]}],
#  ['We want to automate the management of a small municipal library.',
#   {'entities': [[56, 63, 'CLASS']]}],
#  ['For this, we analyzed its operation to obtain the following list of rules and statements:\nMembers have a first name (character string) and a surname (character string).\n',
#   {'entities': [[90, 97, 'CLASS'], [141, 148, 'ATTRIBUTE']]}],
#  ['The library consists of a set of documents and a set of patrons.\n',
#   {'entities': [[4, 11, 'CLASS'], [33, 42, 'CLASS'], [56, 63, 'CLASS']]}],
#  ['Members are subscribed or unsubscribed on a simple request.\n',
#   {'entities': [[0, 7, 'CLASS'],
#     [8, 11, 'RELATIONSHIP'],
#     [12, 22, 'RELATIONSHIP'],
#     [51, 58, 'CLASS']]}],
#  ['New documents are added to the library regularly.\n',
#   {'entities': [[4, 13, 'CLASS'],
#     [14, 17, 'RELATIONSHIP'],
#     [31, 38, 'CLASS']]}],
#  ['These documents are either journals or volumes.\n',
#   {'entities': [[6, 15, 'CLASS'],
#     [16, 19, 'RELATIONSHIP'],
#     [27, 35, 'CLASS'],
#     [39, 46, 'CLASS']]}],
#  ['Volumes are either dictionaries, books or comics.\n',
#   {'entities': [[0, 7, 'CLASS'],
#     [8, 11, 'RELATIONSHIP'],
#     [19, 31, 'CLASS'],
#     [33, 38, 'CLASS'],
#     [42, 48, 'CLASS']]}],
#  ['The documents are characterized by a title (character string).\n',
#   {'entities': [[4, 13, 'CLASS'],
#     [14, 17, 'RELATIONSHIP'],
#     [37, 42, 'ATTRIBUTE']]}],
#  ['Volumes also have an author (character string).',
#   {'entities': [[0, 7, 'CLASS'], [21, 27, 'ATTRIBUTE']]}],
#  ['Bds also have a recipient name (character string).\n',
#   {'entities': [[0, 3, 'CLASS']]}],
#  ['The newspapers have, in addition to the characteristics of the documents, a date of publication (a date).\n',
#   {'entities': [[4, 14, 'CLASS'],
#     [63, 72, 'CLASS'],
#     [76, 80, 'ATTRIBUTE'],
#     [99, 103, 'ATTRIBUTE']]}],
#  ['Only books can be borrowed.\n', {'entities': [[5, 10, 'CLASS']]}],
#  ['A member can borrow or return a book.\n',
#   {'entities': [[2, 8, 'CLASS'],
#     [13, 19, 'RELATIONSHIP'],
#     [32, 36, 'CLASS']]}],
#  ['Members can borrow books (and only books) and it must be possible to know at any time which books a member has borrowed.\n',
#   {'entities': [[0, 7, 'CLASS'],
#     [12, 18, 'RELATIONSHIP'],
#     [19, 24, 'CLASS'],
#     [35, 40, 'CLASS'],
#     [92, 97, 'CLASS'],
#     [100, 106, 'CLASS']]}],
#  ['A member can borrow a maximum of 3 books.\n',
#   {'entities': [[2, 8, 'CLASS'],
#     [13, 19, 'RELATIONSHIP'],
#     [35, 40, 'CLASS']]}],
#  ['The return date for a borrowed book is fixed at the time of the loan.',
#   {'entities': [[11, 15, 'ATTRIBUTE'], [31, 35, 'CLASS']]}],
#  ['This date can be extended upon request.',
#   {'entities': [[5, 9, 'ATTRIBUTE'], [31, 38, 'CLASS']]}],
#  ['ATMs are deceptively simple: although customers only need to press a few buttons to receive cash, there are many layers of security that a safe and effective ATM must pass through to prevent fraud and provide value for banking customers.',
#   {'entities': [[0, 4, 'CLASS'], [38, 47, 'CLASS'], [227, 236, 'CLASS']]}],
#  ['Each customer has a VAT number, a name, a phone number and an address.',
#   {'entities': [[5, 13, 'CLASS'],
#     [34, 38, 'ATTRIBUTE'],
#     [62, 69, 'ATTRIBUTE']]}],
#  ['When a customer wants to send a package to another customer, he just has to login to the company website, select the customer he wants to send the package to, enter the package’s weight and if the delivery is normal or urgent.',
#   {'entities': [[7, 15, 'CLASS'],
#     [25, 29, 'RELATIONSHIP'],
#     [32, 39, 'CLASS'],
#     [51, 59, 'CLASS'],
#     [117, 125, 'CLASS'],
#     [138, 142, 'RELATIONSHIP'],
#     [147, 154, 'CLASS'],
#     [169, 176, 'CLASS'],
#     [179, 185, 'ATTRIBUTE'],
#     [219, 225, 'ATTRIBUTE']]}],
#  ['He then receives an unique identifier code that he writes on the package.',
#   {'entities': [[27, 37, 'ATTRIBUTE'], [65, 72, 'CLASS']]}],
#  ['The package is then delivered by the customer at the delivery center of his choosing.',
#   {'entities': [[4, 11, 'CLASS'], [37, 45, 'CLASS']]}],
#  ['A delivery center has a unique name and an address.',
#   {'entities': [[31, 35, 'ATTRIBUTE'], [43, 50, 'ATTRIBUTE']]}],
#  ['Each client has an associated delivery center.',
#   {'entities': [[5, 11, 'CLASS'], [19, 29, 'RELATIONSHIP']]}],
#  ['This delivery center is chosen by the company and it is normally the one closest to the customer’s house.',
#   {'entities': [[88, 96, 'CLASS']]}],
#  ['The package is them routed through an internal system until it reaches the delivery center of the recipient.',
#   {'entities': [[4, 11, 'CLASS']]}],
#  ['The package is then delivered by hand from that delivery center to the recipient by a courier.',
#   {'entities': [[4, 11, 'CLASS'], [86, 93, 'CLASS']]}],
#  ['Couriers have a single VAT number, a name and a phone number.',
#   {'entities': [[0, 8, 'CLASS'], [37, 41, 'ATTRIBUTE']]}],
#  ['Each courier works in a single delivery center.',
#   {'entities': [[5, 12, 'CLASS']]}],
#  ['A courier is assigned to a packet as soon as the packet is introduced in the system.',
#   {'entities': [[2, 9, 'CLASS'], [27, 33, 'CLASS'], [49, 55, 'CLASS']]}],
#  ['Consider a document made up of one or more sheets.',
#   {'entities': [[11, 19, 'CLASS'], [43, 49, 'CLASS']]}],
#  ['The sheet includes geo objects and text.',
#   {'entities': [[4, 9, 'CLASS'],
#     [10, 18, 'RELATIONSHIP'],
#     [35, 39, 'CLASS']]}],
#  ['We assume the following two geometric objects: circle and rectangle.',
#   {'entities': [[47, 53, 'CLASS'], [58, 67, 'CLASS']]}],
#  ['Anyone who has carried out a professional activity for 5 years related to the subject of their application may apply for a technological and vocational education diploma from the Center for Validation of Acquired Skills of the Academy of their place of residence. .\n\n',
#   {'entities': [[162, 169, 'CLASS']]}],
#  ["The employee obtains a blank file from the Academy's Acquired Validation Center (CAVA).",
#   {'entities': [[4, 12, 'CLASS']]}],
#  ['After completing the file, the employee sends it to the CAVA.',
#   {'entities': [[31, 39, 'CLASS']]}],
#  ['The file contains the civil status of the candidate (surname, first name, address), a description of his professional activities for 5 years, the diploma requested.',
#   {'entities': [[42, 51, 'CLASS'],
#     [53, 60, 'ATTRIBUTE'],
#     [74, 81, 'ATTRIBUTE'],
#     [146, 153, 'CLASS']]}],
#  ['The CAVA sends the file to the home of the Academy inspector responsible for the diploma concerned.',
#   {'entities': [[51, 60, 'CLASS'], [81, 88, 'CLASS']]}],
#  ['The inspector verifies whether the file is admissible.',
#   {'entities': [[4, 13, 'CLASS']]}],
#  ['That is to say, if the diploma requested corresponds to the professional activities of the candidate for at least 5 years.',
#   {'entities': [[23, 30, 'CLASS'], [91, 100, 'CLASS']]}],
#  ['The inspector communicates his decision to the CAVA, which records it in its database.',
#   {'entities': [[4, 13, 'CLASS']]}],
#  ['If the file is admissible, an acknowledgment of receipt is sent to the candidate; otherwise the file is returned to the candidate with a letter indicating the reasons for the refusal of the file.\n\n',
#   {'entities': [[71, 80, 'CLASS'], [120, 129, 'CLASS']]}],
#  ['There is one jury per diploma.',
#   {'entities': [[13, 17, 'CLASS'], [22, 29, 'CLASS']]}],
#  ['A jury is made up of the Academy inspector responsible for the diploma and teachers.',
#   {'entities': [[2, 6, 'CLASS'],
#     [33, 42, 'CLASS'],
#     [63, 70, 'CLASS'],
#     [75, 83, 'CLASS']]}],
#  ['The CAVA knows the contact details of the teachers who are members of a jury.',
#   {'entities': [[42, 50, 'CLASS'], [72, 76, 'CLASS']]}],
#  ['Each jury meets three times a year.\n\n', {'entities': [[5, 9, 'CLASS']]}],
#  ['The schedule of jury meetings is established by the Academy inspector responsible for the diploma concerned, at the start of the school year.',
#   {'entities': [[16, 20, 'CLASS'], [60, 69, 'CLASS'], [90, 97, 'CLASS']]}],
#  ['Three weeks before a meeting of a jury, the CAVA summons the members of the jury as well as the candidates with a pending diploma application file (concerning the diploma under the responsibility of the jury).',
#   {'entities': [[34, 38, 'CLASS'],
#     [76, 80, 'CLASS'],
#     [122, 129, 'CLASS'],
#     [163, 170, 'CLASS'],
#     [203, 207, 'CLASS']]}],
#  ['At the end of a meeting, the jury draws up minutes in which the decisions of the jury are summarized (acceptance or refusal of the diploma).',
#   {'entities': [[29, 33, 'CLASS'], [81, 85, 'CLASS'], [131, 138, 'CLASS']]}],
#  ['Depending on this report, the CAVA sends a certificate of diploma to the candidates or a refusal of diploma.',
#   {'entities': [[58, 65, 'CLASS'], [100, 107, 'CLASS']]}],
#  ['each type of product has a unique code (barcode label), and the same price for all products of this type.',
#   {'entities': [[13, 20, 'CLASS'],
#     [40, 47, 'ATTRIBUTE'],
#     [69, 74, 'ATTRIBUTE'],
#     [83, 91, 'CLASS']]}],
#  ['each type of product is referenced in a catalog, with its associated price.',
#   {'entities': [[13, 20, 'CLASS'], [69, 74, 'ATTRIBUTE']]}],
#  ['When the price of a product must be modified, the manager modifies its price in the catalog, then on the floor where it is stored.\n',
#   {'entities': [[9, 14, 'ATTRIBUTE'],
#     [20, 27, 'CLASS'],
#     [50, 57, 'CLASS'],
#     [71, 76, 'ATTRIBUTE']]}],
#  ['The cashier identifies himself to start the cash register (with a password).\n',
#   {'entities': [[4, 11, 'CLASS'], [34, 39, 'RELATIONSHIP']]}],
#  ['the cash register will carry out the usual functions of a cash register: subtotal calculation, total calculation, possibility of entering several items with the same code, return of goods with the receipt.',
#   {'entities': [[73, 81, 'ATTRIBUTE'],
#     [95, 100, 'CLASS'],
#     [197, 204, 'CLASS']]}],
#  ['The cash register allows you to edit reports:\n· the receipt which will be given only for an effective sale .',
#   {'entities': [[52, 59, 'CLASS'], [102, 106, 'CLASS']]}],
#  ['it contains the store name, a welcome message, the date and time.',
#   {'entities': [[51, 55, 'ATTRIBUTE'], [60, 64, 'ATTRIBUTE']]}],
#  ['Then for each sale it gives the product code, product description, unit price, quantity and subtotal.',
#   {'entities': [[14, 18, 'CLASS'],
#     [32, 39, 'CLASS'],
#     [46, 53, 'CLASS'],
#     [72, 77, 'ATTRIBUTE'],
#     [79, 87, 'ATTRIBUTE'],
#     [92, 100, 'ATTRIBUTE']]}],
#  ['Finally we find the total including VAT\n· The detailed daily report: list of the detailed set of sales for the day.',
#   {'entities': [[20, 25, 'CLASS'], [36, 39, 'CLASS']]}],
#  ['You are asked to create a database to store cooking recipes and also to manage the stocks of ingredients you have.',
#   {'entities': [[52, 59, 'CLASS'],
#     [90, 92, 'RELATIONSHIP'],
#     [93, 104, 'CLASS'],
#     [109, 113, 'RELATIONSHIP']]}],
#  ['Each recipe has a name, a description, the preparation and cooking time, the number of calories per person, the number of parts and the level of difficulty: difficult, medium or easy.',
#   {'entities': [[5, 11, 'CLASS'],
#     [12, 15, 'RELATIONSHIP'],
#     [18, 22, 'ATTRIBUTE'],
#     [26, 37, 'ATTRIBUTE'],
#     [43, 54, 'ATTRIBUTE'],
#     [84, 86, 'RELATIONSHIP'],
#     [119, 121, 'RELATIONSHIP'],
#     [142, 144, 'RELATIONSHIP'],
#     [145, 155, 'ATTRIBUTE']]}],
#  ['For each recipe you want to know what ingredients are needed and the quantity associated with each ingredient.',
#   {'entities': [[9, 15, 'CLASS'],
#     [38, 49, 'CLASS'],
#     [69, 77, 'ATTRIBUTE'],
#     [99, 109, 'CLASS']]}],
#  ['For each ingredient you have its name and the number of calories per 100 grams of that ingredient.',
#   {'entities': [[9, 19, 'CLASS'],
#     [24, 28, 'RELATIONSHIP'],
#     [33, 37, 'ATTRIBUTE'],
#     [53, 55, 'RELATIONSHIP'],
#     [79, 81, 'RELATIONSHIP'],
#     [87, 97, 'CLASS']]}],
#  ['Each ingredient has a type, for example starch for the ingredient potato.',
#   {'entities': [[5, 15, 'CLASS'],
#     [16, 19, 'RELATIONSHIP'],
#     [22, 26, 'CLASS'],
#     [55, 65, 'CLASS']]}],
#  ['The same ingredient can have several packaging, for example, the ingredient flour can be stored as a 1 kg or 500 g package.',
#   {'entities': [[9, 19, 'CLASS'],
#     [24, 28, 'RELATIONSHIP'],
#     [37, 46, 'CLASS'],
#     [65, 75, 'CLASS'],
#     [89, 95, 'RELATIONSHIP']]}],
#  ['These two packages will be considered as different products.',
#   {'entities': [[10, 18, 'CLASS'], [51, 59, 'CLASS']]}],
#  ['To manage the stocks of ingredients, the storage location of the products in the housing is memorized.',
#   {'entities': [[21, 23, 'RELATIONSHIP'],
#     [24, 35, 'CLASS'],
#     [41, 48, 'CLASS'],
#     [58, 60, 'RELATIONSHIP'],
#     [65, 73, 'CLASS']]}],
#  ['Each storage is named and for each storage you know which products are stored there.',
#   {'entities': [[5, 12, 'CLASS'],
#     [16, 21, 'ATTRIBUTE'],
#     [35, 42, 'CLASS'],
#     [58, 66, 'CLASS'],
#     [71, 77, 'RELATIONSHIP']]}],
#  ['The same ingredient can be stored in several racks.',
#   {'entities': [[9, 19, 'CLASS'],
#     [27, 33, 'RELATIONSHIP'],
#     [45, 50, 'ATTRIBUTE']]}],
#  ['A bank system contains data on customers \n(identified by name and address) and \ntheir accounts.\n',
#   {'entities': [[31, 40, 'CLASS'],
#     [57, 61, 'ATTRIBUTE'],
#     [66, 73, 'ATTRIBUTE'],
#     [86, 94, 'CLASS']]}],
#  ['Each account has a balance and there are 2 \ntype of accounts: one for savings which \noffers an interest rate, the other for \ninvestments, used to buy stocks.\n',
#   {'entities': [[5, 12, 'CLASS'],
#     [19, 26, 'ATTRIBUTE'],
#     [52, 60, 'CLASS'],
#     [70, 77, 'CLASS'],
#     [125, 136, 'CLASS'],
#     [150, 156, 'CLASS']]}],
#  ['Stocks are bought at a certain quantity for \na certain price (ticker) and the bank \napplies commission on stock orders.',
#   {'entities': [[0, 6, 'CLASS'],
#     [31, 39, 'ATTRIBUTE'],
#     [62, 68, 'ATTRIBUTE'],
#     [84, 91, 'RELATIONSHIP'],
#     [92, 102, 'ATTRIBUTE']]}],
#  ['Consider an information system that concerns the monitoring of the personnel of a set of local agencies.',
#   {'entities': [[67, 76, 'CLASS'], [95, 103, 'CLASS']]}],
#  ['Each agency is located in a region, each region is managed by a regional management.',
#   {'entities': [[5, 11, 'CLASS'],
#     [28, 34, 'CLASS'],
#     [41, 47, 'CLASS'],
#     [64, 72, 'CLASS']]}],
#  ['The regional management is in charge of a set of local agencies.\n',
#   {'entities': [[4, 12, 'CLASS'], [55, 63, 'CLASS']]}],
#  ['a regional directorate is characterized by a code and a wording.',
#   {'entities': [[2, 10, 'CLASS'],
#     [45, 49, 'ATTRIBUTE'],
#     [56, 63, 'ATTRIBUTE']]}],
#  ['We want to model a system for management of flights and pilots.\n',
#   {'entities': [[44, 51, 'CLASS'], [56, 62, 'CLASS']]}],
#  ['An airline operates flights.',
#   {'entities': [[3, 10, 'CLASS'],
#     [11, 19, 'RELATIONSHIP'],
#     [20, 27, 'CLASS']]}],
#  ['Each airline has an ID.\n',
#   {'entities': [[5, 12, 'CLASS'],
#     [13, 16, 'RELATIONSHIP'],
#     [20, 22, 'ATTRIBUTE']]}],
#  ['Each flight has an ID a departure airport and an arrival airport: an \nairport as a unique identifier.\n',
#   {'entities': [[5, 11, 'CLASS'],
#     [12, 15, 'RELATIONSHIP'],
#     [19, 21, 'ATTRIBUTE'],
#     [34, 41, 'CLASS'],
#     [57, 64, 'CLASS'],
#     [70, 77, 'CLASS'],
#     [90, 100, 'ATTRIBUTE']]}],
#  ['Each flight has a pilot and a co-pilot, and it uses an aircraft of a \ncertain type; a flight has also a departure time and an arrival time. \n',
#   {'entities': [[5, 11, 'CLASS'],
#     [12, 15, 'RELATIONSHIP'],
#     [18, 23, 'CLASS'],
#     [33, 38, 'CLASS'],
#     [47, 51, 'RELATIONSHIP'],
#     [55, 63, 'CLASS'],
#     [86, 92, 'CLASS'],
#     [93, 96, 'RELATIONSHIP']]}],
#  ['An airline owns a set of aircrafts of different types. \n',
#   {'entities': [[3, 10, 'CLASS'],
#     [11, 15, 'RELATIONSHIP'],
#     [25, 34, 'CLASS']]}],
#  ['An aircraft can be in a working state or it can be under repair. \n',
#   {'entities': [[3, 11, 'CLASS'], [57, 63, 'ATTRIBUTE']]}],
#  ['In a particular moment an aircraft can be landed or airborne. \n',
#   {'entities': [[26, 34, 'CLASS'], [42, 48, 'ATTRIBUTE']]}],
#  ['A company has a set of pilots: each pilot has an experience level:\n1 is minimum, 3 is maximum.\n',
#   {'entities': [[10, 13, 'RELATIONSHIP'],
#     [23, 29, 'CLASS'],
#     [36, 41, 'CLASS'],
#     [42, 45, 'RELATIONSHIP']]}],
#  ['A type of aeroplane may need a particular number of pilots, with a \ndifferent role (e.g.: captain, co-pilot, navigator): there must be at least \none captain and one co-pilot, and a captain must have a level 3.',
#   {'entities': [[52, 58, 'CLASS'], [102, 107, 'CLASS'], [168, 173, 'CLASS']]}],
#  ['A hotel is composed of at least two rooms.',
#   {'entities': [[2, 7, 'CLASS'], [36, 41, 'CLASS']]}],
#  ['Each room has a bathroom: shower or bath.',
#   {'entities': [[5, 9, 'CLASS'],
#     [10, 13, 'RELATIONSHIP'],
#     [16, 24, 'CLASS'],
#     [26, 32, 'CLASS'],
#     [36, 40, 'CLASS']]}],
#  ['A hotel accommodates people.',
#   {'entities': [[2, 7, 'CLASS'], [21, 27, 'CLASS']]}],
#  ['It can employ staff and it must be managed by a manager.',
#   {'entities': [[7, 13, 'RELATIONSHIP'],
#     [14, 19, 'CLASS'],
#     [48, 55, 'CLASS']]}],
#  ['Only the first and last names of the employees, managers and occupants are known.',
#   {'entities': [[9, 14, 'ATTRIBUTE'],
#     [37, 46, 'CLASS'],
#     [48, 56, 'CLASS'],
#     [61, 70, 'CLASS']]}],
#  ['Some people are children and others are adults (it is forbidden to employ children).',
#   {'entities': [[5, 11, 'CLASS'], [67, 73, 'RELATIONSHIP']]}],
#  ['A hotel has the following characteristics: an address, a number of rooms and a category.',
#   {'entities': [[2, 7, 'CLASS'],
#     [8, 11, 'RELATIONSHIP'],
#     [46, 53, 'ATTRIBUTE'],
#     [57, 63, 'ATTRIBUTE'],
#     [67, 72, 'CLASS'],
#     [79, 87, 'ATTRIBUTE']]}],
#  ['A room is characterized by the number and beds it contains, its price and its number.',
#   {'entities': [[2, 6, 'CLASS'],
#     [31, 37, 'ATTRIBUTE'],
#     [42, 46, 'ATTRIBUTE'],
#     [64, 69, 'ATTRIBUTE'],
#     [78, 84, 'ATTRIBUTE']]}],
#  ['We want to know who occupies which room on which date.',
#   {'entities': [[35, 39, 'CLASS']]}],
#  ['For each day of the year, we want to be able to calculate the rent of each room according to its price and its occupation (the rent is null if the room is unoccupied).',
#   {'entities': [[75, 79, 'CLASS'],
#     [97, 102, 'ATTRIBUTE'],
#     [147, 151, 'CLASS']]}],
#  ['The sum of these rents allows to calculate the turnover of the hotel between two dates.',
#   {'entities': [[63, 68, 'CLASS']]}],
#  ['A company has several warehouses located in different cities.',
#   {'entities': [[2, 9, 'CLASS'],
#     [10, 13, 'RELATIONSHIP'],
#     [22, 32, 'CLASS'],
#     [54, 60, 'CLASS']]}],
#  ['In each of the warehouses is stored merchandise, the different products it needs for its activity.',
#   {'entities': [[15, 25, 'CLASS'],
#     [29, 35, 'RELATIONSHIP'],
#     [36, 47, 'CLASS'],
#     [63, 71, 'CLASS'],
#     [85, 88, 'RELATIONSHIP']]}],
#  ['Two different warehouses can have the same products.',
#   {'entities': [[14, 24, 'CLASS'], [43, 51, 'CLASS']]}],
#  ['For each product we also want to know its supplier (name, address), its name, whether it is toxic or not and what volume it occupies.',
#   {'entities': [[9, 16, 'CLASS'],
#     [38, 41, 'RELATIONSHIP'],
#     [42, 50, 'CLASS'],
#     [52, 56, 'ATTRIBUTE'],
#     [58, 65, 'ATTRIBUTE'],
#     [68, 71, 'RELATIONSHIP'],
#     [72, 76, 'ATTRIBUTE'],
#     [92, 97, 'ATTRIBUTE'],
#     [114, 120, 'ATTRIBUTE']]}],
#  ['For each warehouse we want to know its surface and its address.',
#   {'entities': [[9, 18, 'CLASS'],
#     [35, 38, 'RELATIONSHIP'],
#     [39, 46, 'ATTRIBUTE'],
#     [51, 54, 'RELATIONSHIP'],
#     [55, 62, 'ATTRIBUTE']]}],
#  ['Airlines offer different flights\nA flight is open for booking and closed by order of the company\nA customer can book one or more flights, for different passengers\nA reservation concerns a single flight and a single passenger\nA reservation can be confirmed or canceled\nA flight has a departure airport and an arrival airport\nA flight has a day and time of departure, and a day and time of arrival\nA flight may include stopovers in one or more airport(s)\n',
#   {'entities': [[0, 8, 'CLASS'],
#     [9, 14, 'RELATIONSHIP'],
#     [25, 32, 'CLASS'],
#     [35, 41, 'CLASS'],
#     [54, 61, 'CLASS'],
#     [99, 107, 'CLASS'],
#     [112, 116, 'RELATIONSHIP'],
#     [129, 136, 'CLASS'],
#     [152, 162, 'CLASS'],
#     [165, 176, 'CLASS'],
#     [177, 185, 'RELATIONSHIP'],
#     [195, 201, 'CLASS'],
#     [215, 224, 'CLASS'],
#     [227, 238, 'CLASS'],
#     [270, 276, 'CLASS'],
#     [277, 280, 'RELATIONSHIP'],
#     [293, 300, 'CLASS'],
#     [316, 323, 'CLASS'],
#     [326, 332, 'CLASS'],
#     [333, 336, 'RELATIONSHIP'],
#     [398, 404, 'CLASS'],
#     [409, 416, 'RELATIONSHIP'],
#     [417, 426, 'CLASS']]}],
#  ['A stopover has a departure time and an arrival time\nEach airport serves one or more cities',
#   {'entities': [[2, 10, 'CLASS'],
#     [11, 14, 'RELATIONSHIP'],
#     [57, 64, 'CLASS'],
#     [65, 71, 'RELATIONSHIP'],
#     [84, 90, 'CLASS']]}],
#  ['The popular bank in Morocco contains several agencies, it is characterized by its name (popular bank) and directed by a director, has a capital and an address.',
#   {'entities': [[12, 16, 'CLASS'],
#     [17, 19, 'RELATIONSHIP'],
#     [28, 36, 'RELATIONSHIP'],
#     [45, 53, 'CLASS'],
#     [82, 86, 'ATTRIBUTE'],
#     [96, 100, 'CLASS'],
#     [120, 128, 'CLASS'],
#     [130, 133, 'RELATIONSHIP'],
#     [136, 143, 'ATTRIBUTE'],
#     [151, 158, 'ATTRIBUTE']]}],
#  ['THE director of the bank has a name, first name, age and salary (or income).',
#   {'entities': [[4, 12, 'CLASS'],
#     [20, 24, 'CLASS'],
#     [25, 28, 'RELATIONSHIP'],
#     [31, 35, 'ATTRIBUTE'],
#     [43, 47, 'ATTRIBUTE'],
#     [49, 52, 'ATTRIBUTE'],
#     [57, 63, 'ATTRIBUTE']]}],
#  ['Each agency has an address, employees and an identifier.',
#   {'entities': [[5, 11, 'CLASS'],
#     [12, 15, 'RELATIONSHIP'],
#     [19, 26, 'ATTRIBUTE'],
#     [28, 37, 'CLASS'],
#     [45, 55, 'ATTRIBUTE']]}],
#  ['Each employee also has a surname, first name and date of hire.',
#   {'entities': [[5, 13, 'CLASS'],
#     [19, 22, 'RELATIONSHIP'],
#     [25, 32, 'ATTRIBUTE'],
#     [40, 44, 'ATTRIBUTE']]}],
#  ['An employee only works in one agency, but can request a transfer to another agency.',
#   {'entities': [[3, 11, 'CLASS'],
#     [17, 22, 'RELATIONSHIP'],
#     [23, 25, 'RELATIONSHIP'],
#     [30, 36, 'CLASS'],
#     [76, 82, 'CLASS']]}],
#  ['An employee can manage one or more customers, the latter has a single account in a given agency, a name, first name and an address.',
#   {'entities': [[3, 11, 'CLASS'],
#     [16, 22, 'RELATIONSHIP'],
#     [35, 44, 'CLASS'],
#     [57, 60, 'RELATIONSHIP'],
#     [70, 77, 'CLASS'],
#     [78, 80, 'RELATIONSHIP'],
#     [89, 95, 'CLASS'],
#     [99, 103, 'ATTRIBUTE'],
#     [111, 115, 'ATTRIBUTE'],
#     [123, 130, 'ATTRIBUTE']]}],
#  ['Each registered customer is assigned to an employee in the agency.\n',
#   {'entities': [[16, 24, 'CLASS'],
#     [28, 36, 'RELATIONSHIP'],
#     [43, 51, 'CLASS'],
#     [52, 54, 'RELATIONSHIP'],
#     [59, 65, 'CLASS']]}],
#  ['An account can either be a paid or unpaid account.',
#   {'entities': [[3, 10, 'CLASS'], [42, 49, 'CLASS']]}],
#  ['Model a LAN in which we find two kinds of printers: ASCII printers can only print ASCII documents.',
#   {'entities': [[42, 50, 'CLASS'],
#     [58, 66, 'CLASS'],
#     [76, 81, 'RELATIONSHIP'],
#     [88, 97, 'CLASS']]}],
#  ['PostScript printers can print either ASCII or Postscript documents.',
#   {'entities': [[11, 19, 'CLASS'],
#     [24, 29, 'RELATIONSHIP'],
#     [57, 66, 'CLASS']]}],
#  ['The documents are sent around as content of packets.',
#   {'entities': [[4, 13, 'CLASS'], [44, 51, 'CLASS']]}],
#  ['For each admitted animal, its name, breed (if any) and owner must be stored.',
#   {'entities': [[18, 24, 'CLASS'],
#     [26, 29, 'RELATIONSHIP'],
#     [30, 34, 'ATTRIBUTE'],
#     [36, 41, 'CLASS'],
#     [55, 60, 'CLASS']]}],
#  ['Each animal should be given an unique numeric identifier.',
#   {'entities': [[5, 11, 'CLASS'], [46, 56, 'ATTRIBUTE']]}],
#  ['For each owner, its name, address and phone number should be stored.',
#   {'entities': [[9, 14, 'CLASS'],
#     [16, 19, 'RELATIONSHIP'],
#     [20, 24, 'ATTRIBUTE'],
#     [26, 33, 'ATTRIBUTE']]}],
#  ['An unique numeric identifier should also be generated for each one of them.',
#   {'entities': [[18, 28, 'ATTRIBUTE']]}],
#  ['An animal might be owner-less.',
#   {'entities': [[3, 9, 'CLASS'], [19, 24, 'CLASS']]}],
#  ['This happens frequently as the clinic often rescues abandoned dogs from the streets in order to treat them and get them new owners.',
#   {'entities': [[124, 130, 'CLASS']]}],
#  ['It should be possible to store information about a specific breed even if no animals of that breed have been treated at the clinic.',
#   {'entities': [[60, 65, 'CLASS'], [77, 84, 'CLASS'], [93, 98, 'CLASS']]}],
#  ['Each appointement always has a responsible physician.',
#   {'entities': [[5, 17, 'CLASS'],
#     [25, 28, 'RELATIONSHIP'],
#     [43, 52, 'CLASS']]}],
#  ['All appointements start at a certain date and time; and are attended by an animal (and of course its owner).',
#   {'entities': [[4, 17, 'CLASS'],
#     [37, 41, 'ATTRIBUTE'],
#     [46, 50, 'ATTRIBUTE'],
#     [75, 81, 'CLASS'],
#     [97, 100, 'RELATIONSHIP'],
#     [101, 106, 'CLASS']]}],
#  ['For each physician, his name, address and phone number should be stored.',
#   {'entities': [[9, 18, 'CLASS'],
#     [24, 28, 'ATTRIBUTE'],
#     [30, 37, 'ATTRIBUTE']]}],
#  ['An unique numeric identifier should also be generated for each one of them.',
#   {'entities': [[18, 28, 'ATTRIBUTE']]}],
#  ['In an appointement, several medical conditions might be detected.',
#   {'entities': [[6, 18, 'CLASS'],
#     [36, 46, 'CLASS'],
#     [56, 64, 'RELATIONSHIP']]}],
#  ['Each condition has a common name and a scientific name.',
#   {'entities': [[5, 14, 'CLASS'],
#     [15, 18, 'RELATIONSHIP'],
#     [28, 32, 'ATTRIBUTE'],
#     [50, 54, 'ATTRIBUTE']]}],
#  ['No two conditions have the same scientific name.',
#   {'entities': [[7, 17, 'CLASS'], [43, 47, 'ATTRIBUTE']]}],
#  ['It should be possible to store information about the most common conditions for each different breed in the database.',
#   {'entities': [[65, 75, 'CLASS'], [95, 100, 'CLASS']]}],
#  ['Let the following sentences apply: A directory contains files.',
#   {'entities': [[37, 46, 'CLASS'],
#     [47, 55, 'RELATIONSHIP'],
#     [56, 61, 'CLASS']]}],
#  ['A room contains walls.',
#   {'entities': [[2, 6, 'CLASS'], [7, 15, 'RELATIONSHIP'], [16, 21, 'CLASS']]}],
#  ['Modems and keyboards are input/output devices.',
#   {'entities': [[0, 6, 'CLASS'], [11, 20, 'CLASS'], [38, 45, 'CLASS']]}],
#  ['A stock exchange transaction is a purchase or a sale.',
#   {'entities': [[34, 42, 'CLASS'], [48, 52, 'CLASS']]}],
#  ['A bank account can belong to a natural or legal person',
#   {'entities': [[48, 54, 'CLASS']]}],
#  ['Each hotel contains a number of rooms, each room is rented by a fixed price.',
#   {'entities': [[5, 10, 'CLASS'],
#     [11, 19, 'RELATIONSHIP'],
#     [32, 37, 'CLASS'],
#     [44, 48, 'CLASS'],
#     [70, 75, 'ATTRIBUTE']]}],
#  ['The manager of the hotel manages the rental of the rooms.\n',
#   {'entities': [[4, 11, 'CLASS'],
#     [19, 24, 'CLASS'],
#     [25, 32, 'RELATIONSHIP'],
#     [51, 56, 'CLASS']]}],
#  ['Access to the bathrooms is free since it is included in the price of the rooms.',
#   {'entities': [[14, 23, 'CLASS'], [60, 65, 'ATTRIBUTE'], [73, 78, 'CLASS']]}],
#  ['Some rooms do not have a bathroom.',
#   {'entities': [[5, 10, 'CLASS'], [25, 33, 'CLASS']]}],
#  ['The other rooms, such as kitchen, reception hall, are not part of the study.',
#   {'entities': [[10, 15, 'CLASS']]}],
#  ['People can rent one or more rooms in the hotel.',
#   {'entities': [[0, 6, 'CLASS'],
#     [11, 15, 'RELATIONSHIP'],
#     [28, 33, 'CLASS'],
#     [41, 46, 'CLASS']]}],
#  ['In other words: the hotel accommodates a certain number of people.\n',
#   {'entities': [[20, 25, 'CLASS'],
#     [26, 38, 'RELATIONSHIP'],
#     [59, 65, 'CLASS']]}],
#  ['The reservation of a room is made by a customer, the manager looks for a free room, if there is the manager gives the price of the room to the customer who becomes the tenant of the room after having paid.',
#   {'entities': [[4, 15, 'RELATIONSHIP'],
#     [21, 25, 'CLASS'],
#     [39, 47, 'CLASS'],
#     [53, 60, 'CLASS'],
#     [78, 82, 'CLASS'],
#     [100, 107, 'CLASS'],
#     [118, 123, 'ATTRIBUTE'],
#     [131, 135, 'CLASS'],
#     [143, 151, 'CLASS'],
#     [182, 186, 'CLASS']]}],
#  ['Otherwise, the customer leaves.', {'entities': [[15, 23, 'CLASS']]}],
#  ['Every day, the mailman delivers registered mail in a geographical area assigned to him.',
#   {'entities': [[15, 22, 'CLASS'],
#     [23, 31, 'RELATIONSHIP'],
#     [43, 47, 'CLASS'],
#     [71, 79, 'RELATIONSHIP']]}],
#  ['The inhabitants are also associated with a geographical area.',
#   {'entities': [[4, 15, 'CLASS'], [25, 35, 'RELATIONSHIP']]}],
#  ['There are two types of registered mail: letters and parcels.',
#   {'entities': [[34, 38, 'CLASS'], [40, 47, 'CLASS'], [52, 59, 'CLASS']]}],
#  ['As several letter carriers can intervene in the same area, we want, for each registered letter, the letter carrier who delivered it, in addition to the addressee.',
#   {'entities': [[11, 17, 'CLASS'], [88, 94, 'CLASS'], [100, 106, 'CLASS']]}],
#  ['Each ingredient has a name, a measuring unit (e.g. olive oil is measured in liters, while eggs are unit based) and a quantity in stock.',
#   {'entities': [[5, 15, 'CLASS'],
#     [22, 26, 'ATTRIBUTE'],
#     [117, 125, 'ATTRIBUTE']]}],
#  ['There are no two ingredients with the same name.\n',
#   {'entities': [[17, 28, 'CLASS'], [43, 47, 'ATTRIBUTE']]}],
#  ['Each dish is composed of several ingredients in a certain quantity.',
#   {'entities': [[5, 9, 'CLASS'],
#     [13, 21, 'RELATIONSHIP'],
#     [33, 44, 'CLASS'],
#     [58, 66, 'ATTRIBUTE']]}],
#  ['An ingredient can, of course, be used in different dishes.',
#   {'entities': [[3, 13, 'CLASS'],
#     [33, 37, 'RELATIONSHIP'],
#     [51, 57, 'CLASS']]}],
#  ['A dish has an unique name and a numeric identifier.',
#   {'entities': [[2, 6, 'CLASS'],
#     [21, 25, 'ATTRIBUTE'],
#     [40, 50, 'ATTRIBUTE']]}],
#  ['There are several tables at the restaurant.',
#   {'entities': [[18, 24, 'CLASS']]}],
#  ['Each one of them has an unique numeric identifier and a maximum ammount of people that can be seated there.',
#   {'entities': [[39, 49, 'ATTRIBUTE'], [75, 81, 'ATTRIBUTE']]}],
#  ['In each meal, several dishes are consumed at a certain table.',
#   {'entities': [[8, 12, 'CLASS'],
#     [22, 28, 'CLASS'],
#     [33, 41, 'RELATIONSHIP'],
#     [55, 60, 'CLASS']]}],
#  ['The same dish can be eaten more than once in the same meal.',
#   {'entities': [[9, 13, 'CLASS'],
#     [21, 26, 'RELATIONSHIP'],
#     [54, 58, 'CLASS']]}],
#  ['A meal takes place in a certain date and has a start and end time.',
#   {'entities': [[2, 6, 'CLASS'],
#     [32, 36, 'ATTRIBUTE'],
#     [47, 52, 'ATTRIBUTE']]}],
#  ['Each meal has a responsible waiter.',
#   {'entities': [[5, 9, 'CLASS'],
#     [16, 27, 'RELATIONSHIP'],
#     [28, 34, 'CLASS']]}],
#  ['A waiter has an unique numerical identifier, a name, an address and a phone number.',
#   {'entities': [[2, 8, 'CLASS'],
#     [33, 43, 'ATTRIBUTE'],
#     [47, 51, 'ATTRIBUTE'],
#     [56, 63, 'ATTRIBUTE']]}],
#  ['In some cases it is important to store information about the client that consumed the meal.',
#   {'entities': [[61, 67, 'CLASS'],
#     [73, 81, 'RELATIONSHIP'],
#     [86, 90, 'CLASS']]}],
#  ['A client has a tax identification number, a name and an address.',
#   {'entities': [[2, 8, 'CLASS'],
#     [44, 48, 'ATTRIBUTE'],
#     [56, 63, 'ATTRIBUTE']]}],
#  ['This subset concerns the follow-up of the personnel of the local agencies located in the regions.',
#   {'entities': [[42, 51, 'CLASS']]}],
#  ['Each region is managed by a regional department which is in charge of a certain number of local agencies.',
#   {'entities': [[5, 11, 'CLASS'],
#     [15, 22, 'RELATIONSHIP'],
#     [60, 66, 'RELATIONSHIP']]}],
#  ['A regional management is characterized by a code and a label.',
#   {'entities': [[44, 48, 'ATTRIBUTE'], [55, 60, 'ATTRIBUTE']]}],
#  ['A factory has several machines.',
#   {'entities': [[2, 9, 'CLASS'],
#     [10, 13, 'RELATIONSHIP'],
#     [22, 30, 'CLASS']]}],
#  ['Each one of them is operated by several workers.',
#   {'entities': [[20, 28, 'RELATIONSHIP'], [40, 47, 'CLASS']]}],
#  ['A worker might work in more than one machine.',
#   {'entities': [[2, 8, 'CLASS'],
#     [15, 19, 'RELATIONSHIP'],
#     [37, 44, 'CLASS']]}],
#  ['In this factory, several products of different types, are produced.',
#   {'entities': [[8, 15, 'CLASS'], [25, 33, 'CLASS']]}],
#  ['Each different type of product is produced in a single machine.',
#   {'entities': [[23, 30, 'CLASS'], [55, 62, 'CLASS']]}],
#  ['But, the same machine can produce more than one type of product.',
#   {'entities': [[14, 21, 'CLASS'],
#     [26, 33, 'RELATIONSHIP'],
#     [56, 63, 'CLASS']]}],
#  ['Products from the same type are all produced from the same single material and have the same weigth.',
#   {'entities': [[0, 8, 'CLASS'],
#     [66, 74, 'ATTRIBUTE'],
#     [93, 99, 'ATTRIBUTE']]}],
#  ['Clients can issue purchase orders.',
#   {'entities': [[0, 7, 'CLASS'],
#     [18, 26, 'RELATIONSHIP'],
#     [27, 33, 'CLASS']]}],
#  ['Each order has a list of the desired products and their quantity.',
#   {'entities': [[5, 10, 'CLASS'],
#     [11, 14, 'RELATIONSHIP'],
#     [37, 45, 'CLASS'],
#     [56, 64, 'ATTRIBUTE']]}],
#  ['For each worker, the following data should be stored in the database: name (first and last), birth date, address and a list of his skills.',
#   {'entities': [[9, 15, 'CLASS'],
#     [70, 74, 'ATTRIBUTE'],
#     [99, 103, 'ATTRIBUTE'],
#     [105, 112, 'ATTRIBUTE'],
#     [131, 137, 'ATTRIBUTE']]}],
#  ['For each machine, the following data should be stored: serial number, make, model and purchase date.',
#   {'entities': [[9, 16, 'CLASS'],
#     [55, 61, 'ATTRIBUTE'],
#     [62, 68, 'ATTRIBUTE'],
#     [70, 74, 'ATTRIBUTE'],
#     [76, 81, 'ATTRIBUTE'],
#     [86, 94, 'RELATIONSHIP'],
#     [95, 99, 'ATTRIBUTE']]}],
#  ['For each client, the followig data should be stored: name, address, phone number and name of the contact person (if any).',
#   {'entities': [[9, 15, 'CLASS'],
#     [53, 57, 'ATTRIBUTE'],
#     [59, 66, 'ATTRIBUTE'],
#     [74, 80, 'ATTRIBUTE'],
#     [85, 89, 'ATTRIBUTE']]}],
#  ['For each purchase order, the following date should be stored: order number, date it has been made, expected and actual delivery date.',
#   {'entities': [[9, 17, 'RELATIONSHIP'],
#     [18, 23, 'CLASS'],
#     [39, 43, 'ATTRIBUTE'],
#     [62, 67, 'CLASS'],
#     [68, 74, 'ATTRIBUTE'],
#     [76, 80, 'ATTRIBUTE'],
#     [84, 87, 'RELATIONSHIP'],
#     [128, 132, 'ATTRIBUTE']]}],
#  ['The operation of the computer system must be as follows:\n\nunloading a truck: when a truck arrives, an employee must enter the characteristics of each item into the system; the system then produces a list with a location for each item;\nloading a truck: the characteristics of the items to be loaded into a truck are entered by an employee in order to indicate to the system to free up slots.\n',
#   {'entities': [[58, 67, 'CLASS'],
#     [102, 110, 'CLASS'],
#     [150, 154, 'CLASS'],
#     [229, 233, 'CLASS'],
#     [279, 284, 'CLASS'],
#     [329, 337, 'CLASS'],
#     [384, 389, 'CLASS']]}],
#  ['Loading and unloading is done manually.\n\n',
#   {'entities': [[12, 21, 'CLASS']]}],
#  ['Warehouse employees are under the responsibility of a manager whose role is to supervise the proper application of the instructions.',
#   {'entities': [[0, 9, 'CLASS'],
#     [10, 19, 'CLASS'],
#     [54, 61, 'CLASS'],
#     [79, 88, 'RELATIONSHIP'],
#     [119, 131, 'CLASS']]}],
#  ['Cinemas are composed of several rooms.',
#   {'entities': [[0, 7, 'CLASS'],
#     [12, 20, 'RELATIONSHIP'],
#     [32, 37, 'CLASS']]}],
#  ['Films are shown in theaters.',
#   {'entities': [[0, 5, 'CLASS'],
#     [10, 15, 'RELATIONSHIP'],
#     [19, 27, 'CLASS']]}],
#  ['A house may have any number of pets living in it.',
#   {'entities': [[2, 7, 'CLASS'], [31, 35, 'CLASS']]}],
#  ['The two possible types of pets that can live in a house are dogs and cats.',
#   {'entities': [[26, 30, 'CLASS'],
#     [40, 44, 'RELATIONSHIP'],
#     [50, 55, 'CLASS'],
#     [60, 64, 'CLASS'],
#     [69, 73, 'CLASS']]}],
#  ['Each dog or cat has a name.',
#   {'entities': [[5, 8, 'CLASS'], [12, 15, 'CLASS'], [22, 26, 'ATTRIBUTE']]}],
#  ['An animal’s house is its one and only home.',
#   {'entities': [[12, 17, 'CLASS']]}],
#  ['A real estate agency lists a number of properties of different types for sale.',
#   {'entities': [[14, 20, 'CLASS'], [39, 49, 'CLASS']]}],
#  ['The maximum number of properties the\nagency can handle at a given time is 100.\n',
#   {'entities': [[22, 32, 'CLASS'], [37, 43, 'CLASS']]}],
#  ['All property entries show the property area in m2\n, number of rooms, neighborhood name, and price.\n',
#   {'entities': [[4, 12, 'CLASS'],
#     [30, 38, 'CLASS'],
#     [39, 43, 'ATTRIBUTE'],
#     [62, 67, 'ATTRIBUTE'],
#     [92, 97, 'ATTRIBUTE']]}],
#  ['Description of each of the types of listed properties include:\nVilla: has a swimming pool or not, and number of adjacent streets\nApartment: on which floor?',
#   {'entities': [[43, 53, 'CLASS'],
#     [54, 61, 'RELATIONSHIP'],
#     [63, 68, 'CLASS'],
#     [129, 138, 'CLASS'],
#     [149, 154, 'ATTRIBUTE']]}],
#  ['and is there a parking lot?\n', {'entities': [[15, 22, 'ATTRIBUTE']]}],
#  ['A company offers several trains.\n',
#   {'entities': [[2, 9, 'CLASS'],
#     [10, 16, 'RELATIONSHIP'],
#     [25, 31, 'CLASS']]}],
#  ['A train is closed or open for reservation.\n',
#   {'entities': [[2, 7, 'CLASS'],
#     [11, 17, 'RELATIONSHIP'],
#     [21, 25, 'RELATIONSHIP'],
#     [30, 41, 'CLASS']]}],
#  ['A customer can book one or more trains.\n',
#   {'entities': [[2, 10, 'CLASS'], [32, 38, 'CLASS']]}],
#  ['Each reservation concerns a single passenger and a single train.\n',
#   {'entities': [[5, 16, 'CLASS'],
#     [17, 25, 'RELATIONSHIP'],
#     [35, 44, 'CLASS'],
#     [58, 63, 'CLASS']]}],
#  ['Two states for a reservation: either canceled or confirmed.\n',
#   {'entities': [[17, 28, 'CLASS']]}],
#  ['A train has an arrival station or a departure station.\n',
#   {'entities': [[2, 7, 'CLASS'],
#     [8, 11, 'RELATIONSHIP'],
#     [23, 30, 'CLASS'],
#     [36, 45, 'ATTRIBUTE'],
#     [46, 53, 'CLASS']]}],
#  ['A train has a departure day, a departure time, and an arrival time.\n',
#   {'entities': [[2, 7, 'CLASS'],
#     [8, 11, 'RELATIONSHIP'],
#     [14, 23, 'ATTRIBUTE'],
#     [31, 40, 'ATTRIBUTE']]}],
#  ['A train may include stops at stations.\n',
#   {'entities': [[2, 7, 'CLASS'],
#     [12, 19, 'RELATIONSHIP'],
#     [20, 25, 'CLASS']]}],
#  ['A stop has a departure time and an arrival time.\n',
#   {'entities': [[2, 6, 'CLASS'],
#     [7, 10, 'RELATIONSHIP'],
#     [13, 22, 'ATTRIBUTE']]}],
#  ['Each station organizes trips to one or more cities.\n',
#   {'entities': [[5, 12, 'CLASS'],
#     [13, 22, 'RELATIONSHIP'],
#     [44, 50, 'CLASS']]}],
#  ['A station has a name, organizes trips to several cities.\n',
#   {'entities': [[2, 9, 'CLASS'],
#     [10, 13, 'RELATIONSHIP'],
#     [16, 20, 'ATTRIBUTE'],
#     [22, 31, 'RELATIONSHIP'],
#     [49, 55, 'CLASS']]}],
#  ['a station has a name.\n',
#   {'entities': [[2, 9, 'CLASS'],
#     [10, 13, 'RELATIONSHIP'],
#     [16, 20, 'ATTRIBUTE']]}],
#  ['a customer or passenger has a surname, first name, address and telephone number.\n',
#   {'entities': [[2, 10, 'CLASS'],
#     [14, 23, 'CLASS'],
#     [24, 27, 'RELATIONSHIP'],
#     [30, 37, 'ATTRIBUTE'],
#     [45, 49, 'ATTRIBUTE'],
#     [51, 58, 'ATTRIBUTE']]}],
#  ['a company has a name.\n',
#   {'entities': [[2, 9, 'CLASS'],
#     [10, 13, 'RELATIONSHIP'],
#     [16, 20, 'ATTRIBUTE']]}],
#  ['a stop and linked to a departure time and an arrival time.\n',
#   {'entities': [[2, 6, 'CLASS'], [23, 32, 'ATTRIBUTE']]}],
#  ['a city has a name.\n',
#   {'entities': [[2, 6, 'CLASS'],
#     [7, 10, 'RELATIONSHIP'],
#     [13, 17, 'ATTRIBUTE']]}],
#  ['a train has an identifier, a departure and arrival date, a departure and arrival time.',
#   {'entities': [[2, 7, 'CLASS'],
#     [8, 11, 'RELATIONSHIP'],
#     [15, 25, 'ATTRIBUTE'],
#     [29, 38, 'ATTRIBUTE'],
#     [59, 68, 'ATTRIBUTE']]}],
#  ['An employee takes care of registering the loans of members who want to borrow the CD-ROMs.',
#   {'entities': [[3, 11, 'CLASS'],
#     [26, 37, 'RELATIONSHIP'],
#     [51, 58, 'CLASS'],
#     [71, 77, 'RELATIONSHIP']]}],
#  ['The employee must first authenticate to perform this operation.',
#   {'entities': [[4, 12, 'CLASS']]}],
#  ['must be returned to the library employee after a period of 3 days.',
#   {'entities': [[32, 40, 'CLASS']]}],
#  ['The member can therefore reserve CD-ROMs containing games, each reservation must mention the borrower, the game and the date of reservation.',
#   {'entities': [[4, 10, 'CLASS'],
#     [25, 32, 'RELATIONSHIP'],
#     [52, 57, 'CLASS'],
#     [64, 75, 'CLASS'],
#     [93, 101, 'ATTRIBUTE'],
#     [107, 111, 'ATTRIBUTE'],
#     [120, 124, 'ATTRIBUTE'],
#     [128, 139, 'CLASS']]}],
#  ['The member is notified when the game (cd) returns to the shelves.\n',
#   {'entities': [[4, 10, 'CLASS'], [32, 36, 'ATTRIBUTE']]}],
#  ['The employee can also organize events, to do so he must provide the following information: the minimum and maximum number of participants, the games to be tested, the date of the event and the start time of the event.\n',
#   {'entities': [[4, 12, 'CLASS'],
#     [22, 30, 'RELATIONSHIP'],
#     [31, 37, 'CLASS'],
#     [143, 148, 'CLASS'],
#     [155, 161, 'RELATIONSHIP'],
#     [167, 171, 'ATTRIBUTE'],
#     [179, 184, 'CLASS'],
#     [211, 216, 'CLASS']]}],
#  ['The member who wishes to participate in an event can register provided that there is still space available.',
#   {'entities': [[4, 10, 'CLASS'],
#     [25, 36, 'RELATIONSHIP'],
#     [43, 48, 'CLASS']]}],
#  ['If the member finds an available place then he can pay his subscription online by an external payment system.',
#   {'entities': [[7, 13, 'CLASS'],
#     [51, 54, 'RELATIONSHIP'],
#     [59, 71, 'CLASS']]}],
#  ['A token-ring based local-area-network (LAN) is a network consisting of nodes, in which network packets are sent around.',
#   {'entities': [[30, 37, 'CLASS'],
#     [39, 42, 'CLASS'],
#     [49, 56, 'CLASS'],
#     [71, 76, 'CLASS'],
#     [87, 94, 'CLASS'],
#     [95, 102, 'CLASS']]}],
#  ['Every node has a unique name within the network, and refers to its next node.',
#   {'entities': [[6, 10, 'CLASS'],
#     [24, 28, 'ATTRIBUTE'],
#     [40, 47, 'CLASS'],
#     [67, 71, 'RELATIONSHIP'],
#     [72, 76, 'CLASS']]}],
#  ['Different kinds of nodes exist: workstations are originators of messages; servers and printers are network nodes that can receive messages.',
#   {'entities': [[19, 24, 'CLASS'],
#     [32, 44, 'CLASS'],
#     [74, 81, 'CLASS'],
#     [86, 94, 'CLASS'],
#     [99, 106, 'CLASS'],
#     [107, 112, 'CLASS']]}],
#  ['Packets contain an originator, a destination and content, and are sent around on a network.',
#   {'entities': [[0, 7, 'CLASS'],
#     [19, 29, 'ATTRIBUTE'],
#     [33, 44, 'ATTRIBUTE'],
#     [49, 56, 'ATTRIBUTE'],
#     [83, 90, 'CLASS']]}],
#  ['A LAN is a circular configuration of nodes.',
#   {'entities': [[2, 5, 'CLASS'], [37, 42, 'CLASS']]}],
#  ['Each document is composed of one or more sheets.',
#   {'entities': [[5, 13, 'CLASS'],
#     [17, 25, 'RELATIONSHIP'],
#     [41, 47, 'CLASS']]}],
#  ['A sheet contains text and geometrical objects which constitute two types of graphic objects supporting operations such as: select, copy, cut, paste and move. \n',
#   {'entities': [[2, 7, 'CLASS'], [8, 16, 'RELATIONSHIP'], [17, 21, 'CLASS']]}],
#  ['We consider the following four geometric objects: circle, ellipse, square, rectangle.',
#   {'entities': [[50, 56, 'CLASS'],
#     [58, 65, 'CLASS'],
#     [67, 73, 'CLASS'],
#     [75, 84, 'CLASS']]}]]

# %%
import srsly
import typer
import warnings
from pathlib import Path

import spacy
from spacy.tokens import DocBin

def convert(lang: str, TRAIN_DATA, output_path: Path):
    nlp = spacy.blank(lang)
    db = DocBin()
    for text, annot in TRAIN_DATA:
        doc = nlp.make_doc(text)
        ents = []
        for start, end, label in annot["entities"]:
            span = doc.char_span(start, end, label=label)
            if span is None:
                msg = f"Skipping entity [{start}, {end}, {label}] in the following text because the character span '{doc.text[start:end]}' does not align with token boundaries:\n\n{repr(text)}\n"
                warnings.warn(msg)
            else:
                ents.append(span)
        doc.ents = ents
        db.add(doc)
    db.to_disk(output_path)

# %%
convert("en", TRAIN_DATA, "data/train.spacy")
convert("en", TRAIN_DATA, "data/valid.spacy")

# %%
# !python -m spacy init fill-config base_config.cfg config.cfg
# Out:
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# !python -m spacy train config.cfg --output ./output --paths.train ./data/train.spacy --paths.dev ./data/valid.spacy
# Out:
# ✔ Created output directory: output
# ℹ Saving to output directory: output
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     43.14    0.00    0.00    0.00    0.00
#   3     200        120.31   3293.32   94.61   92.69   96.61    0.95
#   7     400        157.46    848.95   98.23   97.32   99.15    0.98
#  13     600        218.28    563.45   98.79   98.14   99.44    0.99
#  20     800        236.84    415.02   99.10   99.34   98.87    0.99
#  28    1000        297.39    394.55   99.30   98.97   99.62    0.99
#  38    1200        338.10    381.86   99.34   99.43   99.25    0.99
#  51    1400        290.93    351.44   99.62   99.44   99.81    1.00
#  67    1600        308.53    321.15   99.67   99.72   99.62    1.00
#  85    1800        422.11    329.94   99.67   99.72   99.62    1.00
# 109    2000        455.42    346.85   99.67   99.62   99.72    1.00
# 136    2200        386.55    347.74   99.67   99.72   99.62    1.00
# 170    2400        371.85    394.77   99.67   99.72   99.62    1.00
# 203    2600        279.52    377.56   99.67   99.81   99.53    1.00
# 236    2800        271.53    370.53   99.67   99.81   99.53    1.00
# 270    3000        220.80    339.46   99.67   99.91   99.44    1.00
# 303    3200        242.05    331.21   99.67   99.72   99.62    1.00
# 336    3400        285.54    335.67   99.67   99.91   99.44    1.00
# 370    3600        203.19    328.34   99.67   99.81   99.53    1.00
# ✔ Saved pipeline to output directory
# output\model-last
# [2022-12-22 19:37:24,963] [INFO] Set up nlp object from config
# [2022-12-22 19:37:24,980] [INFO] Pipeline: ['tok2vec', 'ner']
# [2022-12-22 19:37:24,984] [INFO] Created vocabulary
# [2022-12-22 19:37:24,985] [INFO] Finished initializing nlp object
# [2022-12-22 19:37:25,315] [INFO] Initialized pipeline components: ['tok2vec', 'ner']

# %%
import spacy

trained_nlp = spacy.load("./output/model-best")
text = "Each customer has a VAT number, a name, a phone number and an address. There are no two clients with the same VAT number. When a customer wants to send a package to another customer, he just has to login to the company website, select the customer he wants to send the package to, enter the package weight and if the delivery is normal or urgent. He then receives a unique identifier code that he writes on the package. The package is then delivered by the customer at the delivery center of his choosing. A delivery center has a unique name and an address. Each client has an associated delivery center. This delivery center is chosen by the company, and it is normally the one closest to the customer house. The package is them routed through an internal system until it reaches the delivery center of the recipient. The package is then delivered by hand from that delivery center to the recipient by a courier. Couriers have a single VAT number, a name and a phone number. Each courier works in a single delivery center. A courier is assigned to a packet as soon as the packet is introduced in the system."
doc = trained_nlp(text)

spacy.displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Each
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     customer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CLASS</span>
# </mark>
#  has a VAT number, a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     name
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ATTRIBUTE</span>
# </mark>
# , a phone number and an
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     address
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ATTRIBUTE</span>
# </mark>
# . There are no two clients with the same VAT number. When a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     customer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CLASS</span>
# </mark>
#  wants to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     send
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">RELATIONSHIP</span>
# </mark>
#  a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     package
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CLASS</span>
# </mark>
#  to another
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     customer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CLASS</span>
# </mark>
# , he just has to login to the company website, select the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     customer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CLASS</span>
# </mark>
#  he wants to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     send
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">RELATIONSHIP</span>
# </mark>
#  the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     package
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CLASS</span>
# </mark>
#  to, enter the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     package
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CLASS</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ATTRIBUTE</span>
# </mark>
#  and if the delivery is normal or
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     urgent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ATTRIBUTE</span>
# </mark>
# . He then receives a unique
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     identifier
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ATTRIBUTE</span>
# </mark>
#  code that he writes on the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     package
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CLASS</span>
# </mark>
# . The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     package
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CLASS</span>
# </mark>
#  is then delivered by the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     customer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CLASS</span>
# </mark>
#  at the delivery center of his choosing. A delivery center has a unique
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     name
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ATTRIBUTE</span>
# </mark>
#  and an
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     address
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ATTRIBUTE</span>
# </mark>
# . Each
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     client
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CLASS</span>
# </mark>
#  has an
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     associated
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">RELATIONSHIP</span>
# </mark>
#  delivery center. This delivery center is chosen by the company, and it is normally the one closest to the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     customer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CLASS</span>
# </mark>
#  house. The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     package
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CLASS</span>
# </mark>
#  is them routed through an internal system until it reaches the delivery center of the recipient. The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     package
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CLASS</span>
# </mar

# %%
nlp = spacy.load("en_core_web_sm")
doc2 = nlp(text)
classes = set()
attributes = set()
relationships = set()
for token, token2 in zip(doc, doc2):
    if token.ent_type_ == "CLASS":
        classes.add(token2.lemma_)
    elif token.ent_type_ == "ATTRIBUTE":
        attributes.add(token2.lemma_)
    elif token.ent_type_ == "RELATIONSHIP":
        relationships.add(token2.text)

# %%
classes
# Out:
# {'client', 'courier', 'customer', 'package', 'packet'}

# %%
attributes
# Out:
# {'address', 'identifi', 'name', 'urgent', 'weight'}

# %%
relationships
# Out:
# {'associated', 'send'}
